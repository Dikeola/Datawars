# %%
Importing the libraries

#to read the dataframe
import pandas as pd
Reading the dataset as a dataframe

# Reading dataframe
df = pd.read_csv('Careem.csv')

df.head()
Booking ID	Trip ID	Service Area	Booking Type	Booked_Date	Car Type	AA1	Passenger	AA	Reference Code	...	Wait Time Min	Trip Currency	Discount	Trip Price	Payment Currency	Payment Price	Amount of Credit Used	Credit ID	Payment Type	Notes
0	1.094435e+09	756104590.0	Karachi	On Demand	Tue Mar 10 2020 12:28:00 GMT+0500 (Pakistan St...	Bike	AA2	B2	AA	NaN	...	8.0	PKR	3	109	PKR	109	NaN	26218.0	Cash	NaN
1	1.092789e+09	754858038.0	Karachi	On Demand	Sun Mar 08 2020 17:38:00 GMT+0500 (Pakistan St...	Bike	AA3	B2	AA	NaN	...	6.0	PKR	3	97	PKR	97	NaN	26218.0	Cash	NaN
2	1.092552e+09	754683006.0	Karachi	On Demand	Sun Mar 08 2020 13:32:00 GMT+0500 (Pakistan St...	Bike	AA4	B3	AA	NaN	...	3.0	PKR	3	77	PKR	77	NaN	26218.0	Cash	NaN
3	1.086480e+09	750123752.0	Karachi	On Demand	Mon Mar 02 2020 17:16:00 GMT+0500 (Pakistan St...	Bike	AA5	B4	AA	NaN	...	9.0	PKR	34	37	PKR	37	NaN	26218.0	Cash	NaN
4	1.077528e+09	743340406.0	Karachi	On Demand	Sat Feb 22 2020 17:50:00 GMT+0500 (Pakistan St...	Bike	AA6	B5	AA	NaN	...	9.0	PKR	0	66	PKR	66	NaN	26218.0	Cash	NaN
5 rows × 37 columns

df.head().T
0	1	2	3	4
Booking ID	1094435360.0	1092788510.0	1092551662.0	1086479903.0	1077527541.0
Trip ID	756104590.0	754858038.0	754683006.0	750123752.0	743340406.0
Service Area	Karachi	Karachi	Karachi	Karachi	Karachi
Booking Type	On Demand	On Demand	On Demand	On Demand	On Demand
Booked_Date	Tue Mar 10 2020 12:28:00 GMT+0500 (Pakistan St...	Sun Mar 08 2020 17:38:00 GMT+0500 (Pakistan St...	Sun Mar 08 2020 13:32:00 GMT+0500 (Pakistan St...	Mon Mar 02 2020 17:16:00 GMT+0500 (Pakistan St...	Sat Feb 22 2020 17:50:00 GMT+0500 (Pakistan St...
Car Type	Bike	Bike	Bike	Bike	Bike
AA1	AA2	AA3	AA4	AA5	AA6
Passenger	B2	B2	B3	B4	B5
AA	AA	AA	AA	AA	AA
Reference Code	NaN	NaN	NaN	NaN	NaN
Rating	NaN	NaN	NaN	NaN	NaN
Pickup Location	Alama Iqbal Masjid - Jamshed Town - Karachi - ...	MCB Bank - M. A. Jinnah Road - Saddar - Karachi	Alama Iqbal Masjid - Jamshed Town - Karachi - ...	[24.87, 67.05]	[24.87, 67.05]
Dropoff Location	Khayaban-e-Bukhari - Khayaban-e-Bukhari - Defe...	HR Computer Academy - Allama Iqbal Colony - Ka...	Kausar Medical Centre - New MA Jinnah Road - K...	HR Computer Academy - Allama Iqbal Colony - Ka...	HR Computer Academy - Allama Iqbal Colony - Ka...
Duration	21	22	14	16	13
Total Distance	9.14	8.28	7.75	4.44	3.96
Moving Distance	8.53853	7.5498	7.38701	3.71403	2.90831
Initial Wait	1	0	0	1	1
In-Journey Wait	7	6	3	8	8
Booked Pickup Time	10-03-2020 12:32 GMT+0500	08-03-2020 17:48 GMT+0500	08-03-2020 13:42 GMT+0500	02-03-2020 17:22 GMT+0500	22-02-2020 17:57 GMT+0500
Captain Arrival Time	10-03-2020 12:31 GMT+0500	08-03-2020 17:48 GMT+0500	08-03-2020 13:42 GMT+0500	02-03-2020 17:21 GMT+0500	22-02-2020 17:56 GMT+0500
Actual Pick-up Time	10-03-2020 12:32 GMT+0500	08-03-2020 17:48 GMT+0500	08-03-2020 13:42 GMT+0500	02-03-2020 17:22 GMT+0500	22-02-2020 17:57 GMT+0500
Drop-off time	10-03-2020 12:53 GMT+0500	08-03-2020 18:10 GMT+0500	08-03-2020 13:56 GMT+0500	02-03-2020 17:38 GMT+0500	22-02-2020 18:10 GMT+0500
Captain	Karim . .	Rana Muhammad Arshad	Mazhar Iqbal	Arshad Khan	Naveed Ullah
Car Make	Careem	Careem	Careem	Careem	Careem
Car Model	Bike-W	Bike.	Bike.	Bike.	Bike.
Tollgate	NaN	NaN	NaN	NaN	NaN
Tollgate Details GMT	NaN	NaN	NaN	NaN	NaN
Wait Time Min	8.0	6.0	3.0	9.0	9.0
Trip Currency	PKR	PKR	PKR	PKR	PKR
Discount	3	3	3	34	0
Trip Price	109	97	77	37	66
Payment Currency	PKR	PKR	PKR	PKR	PKR
Payment Price	109	97	77	37	66
Amount of Credit Used	NaN	NaN	NaN	NaN	NaN
Credit ID	26218.0	26218.0	26218.0	26218.0	26218.0
Payment Type	Cash	Cash	Cash	Cash	Cash
Notes	NaN	NaN	NaN	NaN	NaN
Discovering the dataset

#show the number of cells in the dataframe
print("dataset size: ", df.size)
​
#show the number of records (rows) in the dataframe
print("number of trips: ", len(df))
​
#show the number of features (coulmns) in the dataframe
print("number of features: ", len(df.columns))
dataset size:  38369
number of trips:  1037
number of features:  37

df.dtypes
Booking ID               float64
Trip ID                  float64
Service Area              object
Booking Type              object
Booked_Date               object
Car Type                  object
AA1                       object
Passenger                 object
AA                        object
Reference Code           float64
Rating                   float64
Pickup Location           object
Dropoff Location          object
Duration                   int64
Total Distance            object
Moving Distance          float64
Initial Wait               int64
In-Journey Wait            int64
Booked Pickup Time        object
Captain Arrival Time      object
Actual Pick-up Time       object
Drop-off time             object
Captain                   object
Car Make                  object
Car Model                 object
Tollgate                 float64
Tollgate Details GMT     float64
Wait Time Min            float64
Trip Currency             object
Discount                  object
Trip Price                 int64
Payment Currency          object
Payment Price             object
Amount of Credit Used    float64
Credit ID                float64
Payment Type              object
Notes                     object
dtype: object
Activities
Let's clean the dataset.
3. Find out the missing values in each column

col_missing_values = df.isna().sum()
4. Drop the columns that have more than 1000 missing values

# Write your code here
df.dropna(thresh=37,inplace=True,axis=1)
5. Drop the rows that have a Service Area other than Karachi

df = df.loc[df['Service Area']=='Karachi']
6. Fill the missing values of the column Wait Time Min with the median of the column

df['Wait Time Min'].fillna(df['Wait Time Min'].median(), inplace=True)
​
7. Fill all missing values in Credit ID using backward filling method

df['Credit ID'].fillna(method='bfill',inplace=True)
10. Find and drop duplicate rows based on Booking ID, Trip ID, Car Model, Payment Type, and Pickup Location columns while keeping last row

# Make sure to permanently drop these duplicates.
# Write your code here
df.drop_duplicates(['Booking ID', 'Trip ID', 'Car Model', 'Payment Type', 'Pickup Location'],inplace=True, keep='last')
11. How many users paid with Credit Card in the Column Payment Type?

# Write your code here
df['Payment Type'].value_counts().loc['Credit Card']
119
12. Replace the Car Type having Go Mini with GO Mini

df['Car Type'] = df['Car Type'].replace('Go Mini','GO Mini')
13. Find the trips (rows) whose Column Car Type contains the substring GO & the locations in column Pickup Location contains University

edu_trips_with_GO = df[(df['Car Type'].str.contains('GO'))&(df['Pickup Location'].str.contains('University'))]
14. How many Values in the Column Car Type end with  +

# Write your code here:
df['Car Type'].str.endswith('+').sum()
64
16. Clean the column Wait Time Min by selecting outliers and dropping them

Wait_Time_plot = df['Wait Time Min'].plot(kind='hist')
Wait_Time_plot.set_yscale('log')
Wait_Time_plot.set_xlabel('Wait Time Min')
Wait_Time_plot.set_ylabel('Frequency')
Text(0, 0.5, 'Frequency')


# Write your code here:
from scipy.stats import zscore
zscores = zscore(df['Wait Time Min'])
df = df[abs(zscores)<3.5]
​
17. Clean the column Trip Price by selecting outliers

Price_plot = df['Trip Price'].plot(kind='box')
Price_plot.set_yscale('log')


Q1 = df['Trip Price'].quantile(0.25)
Q3 = df['Trip Price'].quantile(0.75)
IQR = Q3 - Q1
​
mask = ((df['Trip Price'] < Q1 - 1.5 * IQR) | (df['Trip Price'] > Q3 + 1.5 * IQR))
df = df.drop(df.loc[mask].index)
​
18. Clean the column Payment Type by removing invalid values

valid_payment_type = ['Credit Card', 'Cash']
​
df = df[df['Payment Type'].isin(valid_payment_type)]
19. Clean the columns Trip Currency by removing invalid values

valid_currency_type = ['PKR']
​
df = df[df['Trip Currency']=='PKR']
20. Clean the column Total Distance by removing invalid values

mask = df['Total Distance'].apply(lambda a: True if a.isnumeric else False)
df= df[mask]
